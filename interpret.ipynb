# %%
# Later, to load:
from graphformer import GraphFormer  # import your model class

# Recreate model structure first
model_loaded = GraphFormer(
    num_proteins=model.num_proteins,  # same hyperparameters you used
    hidden_dim=model.hidden_dim,
    num_layers=model.num_layers,
    num_heads=model.num_heads,
    dropout=model.dropout
)

# Load weights
model_loaded.load_state_dict(torch.load("graphformer_weights.pt"))
model_loaded.eval()  # set to evaluation mode
